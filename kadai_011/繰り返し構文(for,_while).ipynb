# %%
array = ["水", "金", "地", "火", "木", "土", "天", "海", "冥"]

# 配列arrayの要素をforループで表示する
for planet in array:
    print(planet)

# 配列arrayの要素をwhileループで表示する
i = 0
while i < 9:
    print(array[i])
    i = i + 1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
